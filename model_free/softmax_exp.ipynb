# %%
from softmax import *

# %%
policy,queries,steps,average_returns = train(m=50,k=6,eta=0.5,epsilon=0.1,grid_size=8,danger=[7,1],goal=[4,5],wall=[2,5],horizon=50,coins=None,seed=0,noise=0.1,sparse=False)
# Out:
# 0
# average reward: 4.82048
# average feedback: 1.22
# 1
# average reward: 5.3822399999999995
# average feedback: 1.08
# 2
# average reward: 4.53536
# average feedback: 1.36
# 3
# average reward: 6.3228800000000005
# average feedback: 1.74
# 4
# average reward: 5.12432
# average feedback: 1.28
# 5
# average reward: 6.925440000000001
# average feedback: 1.44
# 6
# average reward: 6.2176
# average feedback: 1.66
# 7
# average reward: 6.80048
# average feedback: 1.92
# 8
# average reward: 8.077760000000001
# average feedback: 1.96
# 9
# average reward: 6.957120000000001
# average feedback: 1.3
# 10
# average reward: 7.177760000000001
# average feedback: 1.54
# 11
# average reward: 7.415520000000002
# average feedback: 1.8
# 12
# average reward: 8.07056
# average feedback: 1.42
# 13
# average reward: 8.836640000000001
# average feedback: 2.2
# 14
# average reward: 8.01312
# average feedback: 1.82
# 15
# average reward: 8.823039999999999
# average feedback: 1.74
# 16
# ...
